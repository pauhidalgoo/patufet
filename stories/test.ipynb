# %%
import pandas as pd

# %%
pd.read_csv("synthetic_stories_dataset.csv")
# Out:
#                                                  Prompt  \
# 0     Create a fun and educational short story in ca...
# 1     Write a short story (5-10 paragraphs), in cata...
# 2     Create a short bedtime story (in catalan) for ...
# 3     Create a fun and educational short story in ca...
# 4     Create a short bedtime story (in catalan) for ...
# ...                                                 ...
# 5839  Create a fun and educational short story in ca...
# 5840  Craft a short, mature and thought-provoking st...
# 5841  Develop a children's story in catalan (5-10 pa...
# 5842  Craft a short, mature and thought-provoking st...
# 5843  Create a fun and educational short story in ca...
#
#                                                   Story
# 0     El Sol era un gran amic de la Lluna. Jugaven j...
# 1     En Pep, un gat molt gandul, estava estirat al ...
# 2     La Clara tenia un avió de joguina que volava d...
# 3     La Marta tenia un problema molt gran. Era hora...
# ...
